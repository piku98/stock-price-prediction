# %%
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import pandas as pd

# %%
df = pd.read_csv('SP500.csv')

# %%
df.head()
# Out:
#        Date  LABEL         Open         High          Low        Close  \
# 0  2008/4/1      0  1326.410034  1370.180054  1326.410034  1370.180054
# 1  2008/4/2      1  1369.959961  1377.949951  1361.550049  1367.530029
# 2  2008/4/3      1  1365.689941  1375.660034  1358.680054  1369.310059
# 3  2008/4/4      1  1369.849976  1380.910034  1362.829956  1370.400024
# 4  2008/4/7      0  1373.689941  1386.739990  1369.020020  1372.540039
#
#          Volume  InterestRate  ExchangeRate    VIX    Gold     Oil  TEDSpread  \
# 0  4.745120e+09          1.77        1.5615  22.68  897.00  100.92       1.30
# 1  4.320440e+09          1.72        1.5618  23.43  893.50  104.83       1.31
# 2  3.920100e+09          1.70        1.5667  23.21  898.25  103.92       1.35
# 3  3.703100e+09          1.67        1.5735  22.45  905.25  106.09       1.40
# 4  3.747780e+09          1.62        1.5713  22.42  914.70  108.91       1.28
#
#    EFFR
# 0  2.38
# 1  2.18
# 2  2.19
# 3  2.26
# 4  2.24

# %%
data_df = df.drop(['Date', 'LABEL'], axis=1)
data_df.head()
# Out:
#           Open         High          Low        Close        Volume  \
# 0  1326.410034  1370.180054  1326.410034  1370.180054  4.745120e+09
# 1  1369.959961  1377.949951  1361.550049  1367.530029  4.320440e+09
# 2  1365.689941  1375.660034  1358.680054  1369.310059  3.920100e+09
# 3  1369.849976  1380.910034  1362.829956  1370.400024  3.703100e+09
# 4  1373.689941  1386.739990  1369.020020  1372.540039  3.747780e+09
#
#    InterestRate  ExchangeRate    VIX    Gold     Oil  TEDSpread  EFFR
# 0          1.77        1.5615  22.68  897.00  100.92       1.30  2.38
# 1          1.72        1.5618  23.43  893.50  104.83       1.31  2.18
# 2          1.70        1.5667  23.21  898.25  103.92       1.35  2.19
# 3          1.67        1.5735  22.45  905.25  106.09       1.40  2.26
# 4          1.62        1.5713  22.42  914.70  108.91       1.28  2.24

# %%
data_df_X = data_df.drop(['Close'], axis=1)[: -1]
data_df_y = data_df['Close'].shift(-1, axis=0)[ : -1]
X = data_df_X.values
y = data_df_y.values
y = y.reshape(-1, 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0, shuffle=False)
X_train
# Out:
# array([[1.32641003e+03, 1.37018005e+03, 1.32641003e+03, ...,
#         1.00920000e+02, 1.30000000e+00, 2.38000000e+00],
#        [1.36995996e+03, 1.37794995e+03, 1.36155005e+03, ...,
#         1.04830000e+02, 1.31000000e+00, 2.18000000e+00],
#        [1.36568994e+03, 1.37566003e+03, 1.35868005e+03, ...,
#         1.03920000e+02, 1.35000000e+00, 2.19000000e+00],
#        ...,
#        [2.04788000e+03, 2.05390991e+03, 2.04314001e+03, ...,
#         3.99100000e+01, 3.10000000e-01, 3.70000000e-01],
#        [2.04863989e+03, 2.05660010e+03, 2.04056995e+03, ...,
#         4.14500000e+01, 3.30000000e-01, 3.70000000e-01],
#        [2.04855005e+03, 2.04855005e+03, 2.03485999e+03, ...,
#         3.82800000e+01, 3.30000000e-01, 3.70000000e-01]])

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lr.score(X_test, y_test)
predictions = lr.predict(X_test)

# %%
plt.scatter([i for i in range(len(y_test))], y_test.flatten(), color='b')
plt.scatter([i for i in range(len(y_test))], predictions, color='r')
plt.show()

# %%
# Out:
# array([[2055.01001 ],
#        [2063.949951],
#        [2059.73999 ],
#        [2072.780029],
#        [2066.129883],
#        [2045.170044],
#        [2066.659912],
#        [2041.910034],
#        [2047.599976],
#        [2041.98999 ],
#        [2061.719971],
#        [2082.419922],
#        [2082.780029],
#        [2080.72998 ],
#        [2094.340088],
#        [2100.800049],
#        [2102.399902],
#        [2091.47998 ],
#        [2091.580078],
#        [2087.790039],
#        [2091.699951],
#        [2095.149902],
#        [2075.810059],
#        [2065.300049],
#        [2063.370117],
#        [2051.120117],
#        [2050.629883],
#        [2058.689941],
#        [2084.389893],
#        [2064.459961],
#        [2064.110107],
#        [2046.609985],
#        [2066.659912],
#        [2047.209961],
#        [2047.630005],
#        [2040.040039],
#        [2052.320068],
#        [2048.040039],
#        [2076.060059],
#        [2090.540039],
#        [2090.100098],
# ...
